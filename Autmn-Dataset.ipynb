# %%
import pandas as pd

# %%
df = pd.read_csv('data-cp.csv')

# %%
df.dtypes
# Out:
# State_Name        object
# District_Name     object
# Crop_Year        float64
# Season            object
# Crop              object
# Area             float64
# Production       float64
# dtype: object

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
autm = df[df.Season== 'Autumn']

# %%
autm
# Out:
#                          State_Name             District_Name  Crop_Year  \
# 64      Andaman and Nicobar Islands                  NICOBARS     2010.0
# 65      Andaman and Nicobar Islands                  NICOBARS     2010.0
# 111     Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN     2010.0
# 112     Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN     2010.0
# 185     Andaman and Nicobar Islands            SOUTH ANDAMANS     2010.0
# 186     Andaman and Nicobar Islands            SOUTH ANDAMANS     2010.0
# 12377                         Assam                     BAKSA     2005.0
# 12407                         Assam                     BAKSA     2006.0
# 12439                         Assam                     BAKSA     2007.0
# 12473                         Assam                     BAKSA     2008.0
# 12507                         Assam                     BAKSA     2009.0
# 12541                         Assam                     BAKSA     2010.0
# ...

# %%
pd.DataFrame(autm.Crop_Year)
# Out:
#         Crop_Year
# 64         2010.0
# 65         2010.0
# 111        2010.0
# 112        2010.0
# 185        2010.0
# 186        2010.0
# 12377      2005.0
# 12407      2006.0
# 12439      2007.0
# 12473      2008.0
# 12507      2009.0
# 12541      2010.0
# 12575      2011.0
# 12576      2011.0
# 12614      2012.0
# 12615      2012.0
# 12652      2013.0
# 12653      2013.0
# 12691      2014.0
# 12692      2014.0
# 12728      1997.0
# 12754      1998.0
# 12782      1999.0
# 12810      2000.0
# 12838      2001.0
# 12870      2002.0
# 12905      2003.0
# 12940      2004.0
# 12968      2005.0
# 12999      2006.0
# ...           ...
# 245925     2010.0
# 245926     2010.0
# 245927     2010.0
# 245928     2010.0
# 245929     2010.0
# 245930     2010.0
# 245958     2011.0
# 245959     2011.0
# 245960     2011.0
# 245961     2011.0
# 245962     2011.0
# 245989     2012.0
# 245990     2012.0
# 245991     2012.0
# 245992     2012.0
# 245993     2012.0
# 245994     2012.0
# 245995     2012.0
# ...
